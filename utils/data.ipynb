# %%
from data import YahooFinance

# %%
yf = YahooFinance(timeout=10)
# Out:
# Yahoo Session wird initialisiert...
# Cookie-Request: HTTP 404
# Yahoo Authentication erfolgreich.
# Crumb: 6HtsE6GNnp...

# %%
yf.get(symbol='MSFT', modules='financial')
# Out:
# {'quoteSummary': {'result': [{'financialData': {'maxAge': 86400,
#      'currentPrice': {'raw': 495.4, 'fmt': '495.40'},
#      'targetHighPrice': {'raw': 870.0, 'fmt': '870.00'},
#      'targetLowPrice': {'raw': 400.0, 'fmt': '400.00'},
#      'targetMeanPrice': {'raw': 569.5583, 'fmt': '569.56'},
#      'targetMedianPrice': {'raw': 550.0, 'fmt': '550.00'},
#      'recommendationMean': {'raw': 1.35714, 'fmt': '1.36'},
#      'recommendationKey': 'strong_buy',
#      'numberOfAnalystOpinions': {'raw': 53, 'fmt': '53', 'longFmt': '53'},
#      'totalCash': {'raw': 76842999808,
#       'fmt': '76.84B',
#       'longFmt': '76,842,999,808'},
#      'totalCashPerShare': {'raw': 10.348, 'fmt': '10.35'},
#      'ebitda': {'raw': 194237005824,
#       'fmt': '194.24B',
#       'longFmt': '194,237,005,824'},
#      'totalDebt': {'raw': 128812998656,
#       'fmt': '128.81B',
#       'longFmt': '128,812,998,656'},
#      'quickRatio': {'raw': 1.099, 'fmt': '1.10'},
# ...

# %%
yf.get(symbol='AAPL', modules='statistics')
# Out:
# {'quoteSummary': {'result': [{'defaultKeyStatistics': {'maxAge': 1,
#      'priceHint': {'raw': 2, 'fmt': '2', 'longFmt': '2'},
#      'enterpriseValue': {'raw': 4486742409216,
#       'fmt': '4.49T',
#       'longFmt': '4,486,742,409,216'},
#      'forwardPE': {'raw': 32.17704, 'fmt': '32.18'},
#      'profitMargins': {'raw': 0.27618998, 'fmt': '27.62%'},
#      'floatShares': {'raw': 14557694550,
#       'fmt': '14.56B',
#       'longFmt': '14,557,694,550'},
#      'sharesOutstanding': {'raw': 14594180000,
#       'fmt': '14.59B',
#       'longFmt': '14,594,180,000'},
#      'sharesShort': {'raw': 141606163,
#       'fmt': '141.61M',
#       'longFmt': '141,606,163'},
#      'sharesShortPriorMonth': {'raw': 140526320,
#       'fmt': '140.53M',
#       'longFmt': '140,526,320'},
#      'sharesShortPreviousMonthDate': {'raw': 1782777600, 'fmt': '2026-06-30'},
#      'dateShortInterest': {'raw': 1785456000, 'fmt': '2026-07-31'},
# ...

# %%
beta = yf.beta("AAPL")
pe = yf.forward_pe("AAPL")
ev = yf.enterprise_value("AAPL")
# Out:
# ════════════════════════════════════════════════════════════
# Beta
# ────────────────────────────────────────────────────────────
# Ticker:       AAPL
# Key:          beta
# Kategorie:    Risiko
# Wert:         1.09
# Rohwert:      1.086
# Datentyp:     float
# Einheit:      dimensionslos
# Bedeutung:    Sensitivität der Aktie gegenüber dem Gesamtmarkt.
# Quelle:       Yahoo Finance
# ════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════
# Forward P/E
# ────────────────────────────────────────────────────────────
# Ticker:       AAPL
# Key:          forwardPE
# Kategorie:    Bewertung
# Wert:         32.18
# Rohwert:      32.17704
# Datentyp:     float
# Einheit:      x
# Bedeutung:    Kurs-Gewinn-Verhältnis auf Basis des erwarteten Gewinns.
# Quelle:       Yahoo Finance
# ════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════
# ...
